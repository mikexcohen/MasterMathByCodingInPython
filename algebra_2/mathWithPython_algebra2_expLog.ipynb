# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Algebra 2
# # VIDEO: Natural exponent and logarithm
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/algebra_2/mathWithPython_algebra2_expLog.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries and functions
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math

# %%
# e^x

x = np.linspace(-3,3,100)

plt.plot(x,np.exp(x))
plt.xlabel('x')
plt.ylabel('$e^x$')
plt.show()

# %%
plt.plot(x,np.log(x))
plt.xlabel('x')
plt.ylabel('log(x)')
plt.show()

# %% [markdown]
# # Exercise

# %%
# visualize that log and e are inverses of each other (positive values only)

x = np.linspace(.0001,10,10)

# plot it both ways
plt.plot(x,np.log(np.exp(x)))
plt.plot(x,np.exp(np.log(x)),'o')

plt.axis('square')
plt.legend({'$\\log(e^x)$','$e^{\\log(x)}$'})
plt.show()
