# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Algebra 2
# # VIDEO: Find a specific point on a Gaussian
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/algebra_2/mathWithPython_algebra2_gauss.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries and functions
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math

# %%
# the key parameter (FWHM - full width at half-maximum)
h = 1

# "Time" variable
t = np.linspace(-3,3,1001)

# gaussian
g = np.exp( -4*np.log(2)*t**2 / h**2 )

# and plot
plt.plot(t,g)
plt.xlabel('t')
plt.ylabel('y')
plt.title('Gaussian with FWHM=' + str(h))
plt.show()

# %%
# find the x-axis value (here variable 't') for a given function value

yVal2find = .5

# apply the formula shown in the slides
tvals = h*np.sqrt( np.log(yVal2find)/(-4*np.log(2)) )

# print out the results
print(tvals,-tvals)

# %% [markdown]
# # Exercise

# %%
N = 100 # number of Gaussians
h = np.zeros(N)

G = np.zeros((N,len(t)))

for i in range(N):
  h[i] = (i+1)/N
  G[i,:] = np.exp( -4*np.log(2)*t**2 / h[i]**2 )

plt.pcolormesh(t,h,G)
plt.xlabel('t')
plt.ylabel('h')
plt.show()
