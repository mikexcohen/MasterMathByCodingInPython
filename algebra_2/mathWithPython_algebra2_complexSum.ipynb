# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Algebra 2
# # VIDEO: Complex numbers: addition and subtraction
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/algebra_2/mathWithPython_algebra2_complexSum.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries and functions
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math

# %%
# some correct and incorrect ways to get the imaginary operator

print( 1j )
print( np.sqrt(-1) ) # doesn't work!
print( np.sqrt(-1,dtype='complex') )
print( (-1)**(1/2) ) # OK but not a good solution
print(sym.I) # in sympy

# %%
# create complex numbers

real_part = 4
imag_part = -6

cn1 = complex(real_part,imag_part)
cn2 = real_part + 1j*imag_part

# %%
# display
print(cn1)
print(cn2)

print( type(cn2) )

# %%
# now for adding and subtracting
z1 = complex(4,5)
z2 = complex(6,-2)

print(z1+z2)
print(z1-z2)

# %%
# extracting the real and imaginary parts of a complex number
print( 'The real part of z is ' + str(np.real(z1)))
print( 'The imaginary part of z is ' + str(np.imag(z1)))

# %% [markdown]
# # Exercise

# %%
# show that the complex addition is real parts summed and imaginary parts summed

w = complex(2,4)
z = complex(5,6)

# sum each part individually
realsum = np.real(w) + np.real(z)
imagsum = np.imag(w) + np.imag(z)

wPlusz1 = complex(realsum,imagsum)

# sum together in one go
wPlusz2 = w+z

print(wPlusz1)
print(wPlusz2)
