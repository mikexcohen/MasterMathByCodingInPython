# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Algebra 2
# # VIDEO: Roots of polynomials
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/algebra_2/mathWithPython_algebra2_polynomialRoots.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries and functions
import sympy as sym
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from IPython.display import display, Math

# %%
### the equation:
# 3x^2 + 2x - 1

# define the coefficients
coefs = [3,2,-1]

# and solve
roots = np.roots(coefs)

print(roots)

# %%
# solve
from sympy.abc import x

eq = 3*x**2 + 2*x - 1

for i in roots:
  display(Math('\\text{At x=}%g\\text{, }%s = %g' %(i,sym.latex(eq),eq.subs(x,i))))

# %%
# zero-degree polynomial
np.roots(8)

# %% [markdown]
# # Exercise

# %%
# for different polynomial degrees, count the number of roots

for i in range(1,11):
  coefs = np.arange(1,i+1)
  print('A degree-%s polynomial has %s roots' %(len(coefs)-1,len(np.roots(coefs))))
