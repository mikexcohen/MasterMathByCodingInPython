# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Algebra 2
# # VIDEO: Log-spaced and linearly spaced numbers
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/algebra_2/mathWithPython_algebra2_loglin.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries and functions
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math

# %%
# you've already seen linearly spaced numbers...

np.linspace(-2,4,10)

# %%
# log-spaced
np.logspace(1,2,10)

# %%
# the way you'd probably expect them to be
a = np.log10(2.3)
b = np.log10(14.3)
n = 14

np.logspace(a,b,n)

# %%
# the way you'd probably expect them to be
a = np.log10(1)
b = np.log10(5)
n = 5

np.logspace(a,b,n)

# %% [markdown]
# # Exercise

# %%
# show that at small scales, lin and log are close.
# this is why local linear approximations to nonlinear functions are so useful

a = 2
b = 100
n = 50

lo = np.logspace(np.log10(a),np.log10(b),n)
li = np.linspace(a,b,n)

plt.plot(li,lo,label='log')
plt.plot(li,li,label='linear')

plt.legend()
plt.axis('square')
plt.show()
