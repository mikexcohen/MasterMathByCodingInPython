# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Algebra 1
# # VIDEO: Algebra 1 bug hunt! (solutions)
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MasterMathByCodingInPython/blob/main/algebra_1/mathWithPython_algebra1_bugHunt_SOL.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries
import sympy as sym
import numpy as np
from IPython.display import display, Math

# %%
# from sympy.abc import x2
x2 = sym.symbols('x2')

x2 = 4

# %%
a,b,c,d = sym.symbols('a,b,c,d')

expr = 4*b + 5*a*a - c**3 + 5*d

# %%
import math
math.gcd(30,50)

# %%
from sympy.abc import x

expr = 4*x - 8
sym.solve(expr)

# %%
import numpy as np

A = np.array( [ [1,2],[3,4] ] )
# make it look nice
display(Math(sym.latex(sym.sympify(A))))

# %%
fact_dict = sym.factorint(44)
allkeys = fact_dict.keys()

for i in fact_dict:
    print('%g was present %g times.' %(i,fact_dict[i]))

# %%
x,y = sym.symbols('x,y')

expr = 4*x - 5*y**2

expr.subs({x:5})

# %%
# goal is to show a fraction

f = sym.sympify(5)/9

display(Math(sym.latex(f)))

# %%
# print the last 3 items from a list
lst = [1,3,2,5,4,6,7,5,3,7]
lst[-3:]

# %%
from sympy.abc import x,y

expr = 2*x + 4*y

# solve for y
sym.solve(expr,y)

# %%
import numpy as np

A = np.array( [ [1,2],[3,4] ] )

# set the element in the second row, second column to 9
A[1,1] = 9
print(A)
