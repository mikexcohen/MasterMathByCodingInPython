# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Arithmetic
# # VIDEO: Arithmetic bug hunt!
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/arithmetic/mathWithPython_arithmetic_bugHunt_SOL.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ### Note about this code: The code below shows the SOLUTIONS!
#
# You should first go through the file called "mathWithPython_arithmetic_bugHunt.ipynb."
#
# Then you can check your answers here!

# %%
x = '1'
y = '2'

print( int(x) + int(y) )

# %%
display(Math('\\frac{1}{2}'))

# %%
x = 4
y = 5
display(Math('%g + %g = %g'%(x,y,x+y)))

# %%
display(Math('\\frac{%g}{%g} = %g'%(x,y,x/y)))

# %%
3**2 # should equal 9

# %%
for i in range(0,3):
    display(Math('%g\\times2 = %g'%(i,i*2)))

# %%
a = 10
b = 20

result = 2*a <= b

print(result)

# %%
if a+b*2 > 40:
    print(str(a+b*2) + ' is greater than ' + str(40) + '. Time to celebrate!')

# %%
var = input('input a number!')
print(var)

# %%
# division
4/10

# %%
# sum two numbers
w = float( input('Input a number: ') )
z = float( input('Input another number: ') )

print('The sum of %s and %s is %s' %(w,z,w+z))

# %%
display(Math('\\frac{9}{3} = ' + str(9/3)))

# %%
display(Math('\\frac{9}{3} = ' + str(9/3)))

# %%
# print the numbers 1 through 10
t = 1
while t<11:
    print(t)
    t=t+1
