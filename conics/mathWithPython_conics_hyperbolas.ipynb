# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Graphing conic sections
# # VIDEO: Graphing hyperbolas
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/conics/mathWithPython_conics_hyperbolas.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %%
# parameters
a = 1
b = .5
h = 1
k = 2

# grid space
axlim = 2* (np.max((a,b)) + np.max((abs(h),abs(k))))
x = np.linspace(-axlim,axlim,100)
X,Y = np.meshgrid(x,x)

# create the function
Fxy = (X-h)**2/a**2 - (Y-k)**2/b**2 - 1

# draw it as a contour
plt.contour(X,Y,Fxy,0)

# draw a dot in the center
plt.plot(h,k,'go')

# draw guide lines
plt.plot([-axlim,axlim],[0,0],'--',color=[.8,.8,.8])
plt.plot([0,0],[-axlim,axlim],'k--',color=[.8,.8,.8]) # color overwrites k

plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# # Exercise

# %%
# parameters
n = 16
a = np.linspace(1,5,n)
b = np.linspace(1,5,n)

# grid space
axlim = 8
x = np.linspace(-axlim,axlim,100)
y = np.linspace(-axlim,axlim,100)
X,Y = np.meshgrid(x,y)

for i in range(0,n):
  Fxy = X**2/a[i]**2 - Y**2/b[i]**2 - 1
  plt.contour(X,Y,Fxy,0,colors=[(i/n,0,i/n)])

  Fxy = -X**2/a[i]**2 + Y**2/b[i]**2 - 1
  plt.contour(X,Y,Fxy,0,colors=[(0,i/n,i/n)])

plt.gca().set_aspect('equal')
plt.axis('off')
plt.show()
