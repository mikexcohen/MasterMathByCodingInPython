# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Probability theory
# # VIDEO: Joint probability distributions
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/probability/mathWithPython_prob_jointPDFs.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 1000

x = np.random.randn(n)
y = np.random.randn(n)**2

plt.hist2d(x,y,30,vmax=10)
plt.xlabel('$x$')
plt.ylabel('$x^2$')
plt.show()

# %%
sns.jointplot(x=x,y=y,kind='scatter',color=[.8,.3,.9]).plot_joint(sns.kdeplot)
plt.xlabel('$x$')
plt.ylabel('$x^2$')
plt.show()

# %% [markdown]
# # Exercise

# %%
# import data with pandas, name variables x and y, determine (visually) how many clusters are in the data

import pandas as pd
data = pd.read_csv('data.csv',header=None,names=['x','y'])
data

sns.jointplot(x=data['x'],y=data['y'],kind='kde',levels=5).plot_joint(sns.scatterplot)
plt.show()
