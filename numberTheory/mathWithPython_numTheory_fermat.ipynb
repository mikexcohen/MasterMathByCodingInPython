# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Number theory
# # VIDEO: Fermat's theorem
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/numberTheory/mathWithPython_numTheory_fermat.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym

# %% [markdown]
# There are no integer solutions to $x^3+y^3=z^3$

# %%
ints = np.arange(1,101)

z = np.zeros((len(ints),len(ints)))

# run the simulation
for x in ints:
  for y in ints:
    z[x-1,y-1] = (x**3 + y**3)**(1/3)

# %%
# check for integers
zInts = z%1 == 0

# %%
# now visualize
fig,ax = plt.subplots(1,2,figsize=(12,6))
fig.tight_layout(pad=5)

# show the resulting z-values
h = ax[0].imshow(z)
fig.colorbar(h,ax=ax[0],fraction=.045)
ax[0].set_xlabel('y')
ax[0].set_ylabel('x')
ax[0].set_title('$z=\sqrt[3]{x^3+y^3}$',fontsize=16)

# show the boolean integer map
h = ax[1].imshow(zInts,vmin=0,vmax=1)
fig.colorbar(h,ax=ax[1],fraction=.045)
ax[1].set_xlabel('y')
ax[1].set_ylabel('x')
ax[1].set_title('Whether $z$ is int',fontsize=16)

plt.show()

# %% [markdown]
# # Exercise: "Fermat's stairway to heaven"

# %%
# Modify the code to create a map of integer Pythagorean triplets
