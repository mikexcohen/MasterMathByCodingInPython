# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Algebra 2
# # VIDEO: Complex numbers: conjugate and multiplication
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/algebra_2/mathWithPython_algebra2_complexMult.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries and functions
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math

# %%
# create complex numbers
z1 = complex(4,5)
z2 = complex(6,-2)

# multiplication the "manual" way
w = np.real(z1)*np.real(z2) + np.real(z1)*np.imag(z2)*1j + np.imag(z1)*np.real(z2)*1j + np.imag(z1)*np.imag(z2)*1j*1j

print(w)
sym.sympify(w)

# %%
# or let Python do the hard work ;)
sym.sympify(z1*z2)

# %%
# complex conjugate

z1 = complex(4,3)
z2 = complex(4,-3)

print( np.conj(z1) )
print( np.conj(z2) )

# %% [markdown]
# # Exercise

# %%
a,b = sym.symbols('a,b')#,real=True)

z = a + b*sym.I

sym.simplify( sym.expand( z*sym.conjugate(z) ) )

# %%
# with nicer printing

result = sym.simplify( sym.expand( z*sym.conjugate(z) ) )
display(Math('z\\times z^* = %s' %sym.latex(result)))
